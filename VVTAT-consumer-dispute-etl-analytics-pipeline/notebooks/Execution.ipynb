# %%
# %run "00_globals_and_db.ipynb"
# %run "01_discover_years.ipynb"
# %run "02_collect_case_rows.ipynb"
# %run "05_preflight_skip_checks.ipynb"
# %run "03_download_pdfs.ipynb"
# %run "05_preflight_skip_checks.ipynb"
# %run "04_parse_pdfs.ipynb"

# %%
# %run "05_preflight_skip_checks.ipynb"
# %run "04_parse_pdfs.ipynb"
